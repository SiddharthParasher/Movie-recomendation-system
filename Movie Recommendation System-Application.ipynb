# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import sigmoid_kernel
from pywebio.input import *
from pywebio.output import *
import time
from pywebio.platform.flask import webio_view
from pywebio import STATIC_PATH
from flask import Flask, send_from_directory
app = Flask(__name__)
column_names = ["item_id", "movie_title", "release date", "video release date", "IMDb URL", "unknown", "Action", "Adventure", "Animation", "Children's", "Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"]
item = pd.read_csv("ml-100k/ml-100k/u.item", sep='|', names = column_names, encoding='latin-1')

movies_list = list(item['movie_title'])
# Keep track of movie title corresponding to the index of dataframe
index_movie_dict = {}
for i in range(len(item)):
    index_movie_dict[i] = item.loc[i]['movie_title']

# Keep track of index of dataframe corresponding to the movie title
movie_index_dict = {}
for i in range(len(item)):
    movie_index_dict[item.loc[i]['movie_title']] = i
# Keep track of release date corresponding to movie title
release_date = item['release date']
movie_release_date_dict = {}
for i in range(len(item)):
    movie_release_date_dict[movies_list[i]] = release_date[i]

item.drop(["item_id", "movie_title", "release date", "video release date", "IMDb URL"], axis = 1, inplace = True)
genres = item.to_numpy()

from sklearn.metrics.pairwise import sigmoid_kernel
genres_similarity_matrix = sigmoid_kernel(genres, genres)

item = pd.read_csv("ml-100k/ml-100k/u.item", sep='|', names = column_names, encoding='latin-1')
posters = pd.read_csv('movie_poster.csv', names = ['item_id', 'poster_link'])
df = posters.merge(item, on="item_id")
df = df.drop(columns=["unknown", "Action", "Adventure", "Animation", "Children's", "Comedy", "Crime", "Documentary", "Drama", "Fantasy", "Film-Noir", "Horror", "Musical", "Mystery", "Romance", "Sci-Fi", "Thriller", "War", "Western"])

movies_list1 = df['movie_title']
poster_link = df['poster_link']
movie_poster_dict = {}
for i in range(len(df)):
    movie_poster_dict[movies_list1[i]] = poster_link[i]


def recommend():
    img = open('movies.jpg', 'rb').read()
    put_image(img, width='900px')
    put_markdown('# **Movie Recommendation System by `Sid Michaelson`**')
    put_html('<h1 style="font-size:20px; text-align:center; color:blue; background-color:powderblue;">Welcome to Hollywood!<br></h1>')
    
    recently_watched_movie = select('Enter one of the movies from the database ', movies_list)
    number_of_recommendations = input("Enter the number of recommendations", type = NUMBER)
    
    put_markdown('## Please wait! Your request is being processed!')
    
    #Display Processbar
    put_processbar('bar');
    for i in range(1, 11):
        set_processbar('bar', i / 10)
        time.sleep(0.1)
    
    put_html('<hr>')
    put_markdown("Recommendations for you similar to `%s` movie are as follows: " % recently_watched_movie)
    put_html('<hr>')
    
    idx = movie_index_dict[recently_watched_movie]
    similarity_list = genres_similarity_matrix[idx]
    
    # List of tuples (Similarity value, Index)
    lst = []
    for i in range(len(similarity_list)):
        lst.append((similarity_list[i],i))
    count = 0
    for element in list(sorted(lst, reverse = True)):
        count = count + 1
        if(count == (number_of_recommendations+1)):
            break
        movie_name = index_movie_dict[element[1]]
        put_markdown("# *`%s`*" % movie_name)
        put_text("Release Date: %s" % movie_release_date_dict[movie_name])

        
        # Display movie poster
        if(movie_name in movie_poster_dict.keys()):
            p_link = movie_poster_dict[movie_name]
            put_image(p_link, width = '1000px')
        else:
            put_text('Oops! Enough information not available.')
        put_html('<hr>')



    
    #final_recommendations = recommend_movies(str(recently_watched_movie), int(number_of_recommendations))
    
    


    
app.add_url_rule('/SidMichaelsons', 'webio_view', webio_view(recommend), methods=['GET', 'POST', 'OPTIONS'])
app.run(host='localhost', port=80)
#app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:80/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Aug/2022 21:57:17] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [24/Aug/2022 21:57:41] "GET /tdrs HTTP/1.1" 404 -
# 127.0.0.1 - - [24/Aug/2022 21:57:44] "GET /SidMichaelsons HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:44] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:46] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:46] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:48] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:48] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:50] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:50] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:52] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:52] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:54] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:54] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:56] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:56] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:58] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:57:58] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:00] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:00] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:02] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:02] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:04] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:04] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:06] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:06] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:08] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:08] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:10] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:10] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:12] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:12] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:14] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:14] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:16] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:16] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:18] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:18] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:20] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:20] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:22] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:22] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:24] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:24] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:26] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:26] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:28] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:28] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:30] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:30] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:32] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:32] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:34] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:34] "POST /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:34] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:36] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:36] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:38] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:38] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:40] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:40] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:42] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:42] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:44] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:49] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:50] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:51] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:52] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:53] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:54] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:55] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:56] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:57] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:58] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:58:59] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:00] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:01] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:02] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:03] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:04] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:05] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:06] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:07] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:08] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:09] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:10] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:11] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:12] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:13] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:14] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:15] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:16] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:16] "POST /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:17] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:18] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:19] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:20] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:20] "POST /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:21] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2022 21:59:22] "GET /SidMichaelsons?app=index HTTP/1.1" 200 -

# %%
# try this link https://www.youtube.com/watch?v=sqR154NkwZk
